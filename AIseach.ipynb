# %%
import random
import math
import pandas as pd

# %%
#My cities database
df = pd.read_csv("cities_dataset.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2709989679.py in <cell line: 0>()
#       1 #My cities database
# ----> 2 df = pd.read_csv("cities_dataset.csv")
#
# NameError: name 'pd' is not defined
